# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#using pandas reading both datas...
train_data=pd.read_csv("C:/Users/91979/OneDrive/Documents/jobthon/train.csv")

# %%
train_data.head()
# Out:
#    row_id  user_id  category_id  video_id  age  gender            profession  \
# 0       1    19990           37       128   24    Male               Student
# 1       2     5304           32       132   14  Female               Student
# 2       3     1840           12        24   19    Male               Student
# 3       4    12597           23       112   19    Male               Student
# 4       5    13626           23       112   27    Male  Working Professional
#
#    followers  views  engagement_score
# 0        180   1000              4.33
# 1        330    714              1.79
# 2        180    138              4.35
# 3        220    613              3.77
# 4        220    613              3.13

# %%
test_data=pd.read_csv("C:/Users/91979/OneDrive/Documents/jobthon/test.csv")

# %%
test_data.head()
# Out:
#    row_id  user_id  category_id  video_id  age  gender            profession  \
# 0   89198     7986           12        42   14    Male               Student
# 1   89199    11278           34       115   14    Male               Student
# 2   89200    17245            8       110   44  Female  Working Professional
# 3   89201     9851           16       137   18    Male               Student
# 4   89202    16008           34        96   47  Female                 Other
#
#    followers  views
# 0        180    138
# 1        230    840
# 2        280    628
# 3        270    462
# 4        230    840

# %%
#checking null values
train_data.isnull().sum()   #their is noNull values in train_data
# Out:
# row_id              0
# user_id             0
# category_id         0
# video_id            0
# age                 0
# gender              0
# profession          0
# followers           0
# views               0
# engagement_score    0
# dtype: int64

# %%
test_data.isnull().sum() # their is no nulll values in test_data
# Out:
# row_id         0
# user_id        0
# category_id    0
# video_id       0
# age            0
# gender         0
# profession     0
# followers      0
# views          0
# dtype: int64

# %%
#used heatmap to best way to find out null values..
sns.heatmap(train_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
#used heatmap to best way to find out null values..
sns.heatmap(test_data.isnull(), cbar=False)
# Out:
# <AxesSubplot:>

# %%
train_data.shape
# Out:
# (89197, 10)

# %%
test_data.shape
# Out:
# (11121, 9)

# %%
plt.figure(figsize=(20,10))                                     #ploting heatmap correlation
sns.set_style("darkgrid")  
sns.heatmap(train_data.corr(),annot= True)
plt.show()

# %%
plt.figure(figsize=(20,10))                                      
sns.set_style("darkgrid")  
sns.heatmap(test_data.corr(),annot= True)
plt.show()

# %%
# Out:
#    row_id  user_id  category_id  video_id  age  gender  followers  views  \
# 0       1    19990           37       128   24    Male        180   1000
# 1       2     5304           32       132   14  Female        330    714
# 2       3     1840           12        24   19    Male        180    138
# 3       4    12597           23       112   19    Male        220    613
# 4       5    13626           23       112   27    Male        220    613
#
#    engagement_score  profession_Student  profession_Working Professional
# 0              4.33                   1                                0
# 1              1.79                   1                                0
# 2              4.35                   1                                0
# 3              3.77                   1                                0
# 4              3.13                   0                                1
